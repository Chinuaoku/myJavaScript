# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinuaoku/myJavaScript/blob/main/Javascript_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-550032a0-f62e-4132-9857-93c761a20057" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-550032a0-f62e-4132-9857-93c761a20057">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # FUNDAMENTALS OF JAVASRCIPT
# - This is a programming language that is used to make web pages interactive.
# - It is an interpreted language: means it doesn't have to be compiled like Java or C or Visual basic and things a lot easier. Javascript code doesn't have to run through a compiler or anything of that nature.
# - Runs on the client's computer/browser. Whereas languages like php, ruby-on-rails run on the server. We don't need any kind of server or anything to run it.
# - Object based: It is an object oriented program, prototype based instead of class based.
#
# NOTE: Javascript is NOT Java
# - They have a similar name but are completely different
# - Java is much more complex and a high level language. Typically used to build desktop applications, games etc.
# - Same category as C and C++
# - Javascript is a "scripting" language meaning that it is interpreted by the web browser when the page is loading.
#
# # HTML vs JAVASCRIPT
# - They are completely different and they work together
# - HTML is a markup language (display headings, paragraphs, etc) javascript is a programming language
# - Javascript uses "events" and "actions" to make your page interactive
#
# # What can you do with Javascript?
# - Put content in an HTML page on the fly
# - Make web pages responsive
# - Detect a users browser and other information
# - Create cookies - holding data in memory
# - Validate forms
# - Create animations, slideshows, scrollers, etc
# - Build apps with Javascript Frameworks (Angular, ReactJS, BackboneJS, etc)

# %% [markdown]
# # VARIABLES AND DATA TYPES
# - To write javascript to work with our html file we can either link a javascript file or we can put it right inside html inside script tags. For this course we will use script tags.
# To link an external javascript file, in the head tag we write;
#
#
# ```
# <script src="main.js"></script>
# ```
# ![Screenshot 2025-02-14 235538.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-15 011152.png](data:image/png;base64,...)

# %% [markdown]
# # Data Types
# - Numbers
# - String
# - Array
# - Object
#
# # Creating a variable with 'var'
#
# ```
# var number1 = 35;
# ```
# - It doesnt have quotes around it so it'll be looked at as a number. If it had double or single quotes it'd be looked at as a string.
# ![Screenshot 2025-02-15 012043.png](data:image/png;base64,...)

# %% [markdown]
# - When you have varibale that are numbers you can perform maths operations.
# ![Screenshot 2025-02-15 012445.png](data:image/png;base64,...)

# %% [markdown]
# - Lets change the number data types by putting quotes around them, you'd notice the result will be a concatenation of the variables.
# ![Screenshot 2025-02-15 012717.png](data:image/png;base64,...)

# %% [markdown]
# - Concatenating string and string variable
# ![Screenshot 2025-02-15 012951.png](data:image/png;base64,...)

# %% [markdown]
# # Naming conventions of variables
# - Variables can contain letters, numbers, underscores, dollar sign. These are the characters used in variables.
# - They should begin with a letter
# - They can also be started with an underscore or dollar sign
# - Variable names are case sensitive
# ![Screenshot 2025-02-15 014057.png](data:image/png;base64,...)

# %% [markdown]
# - Upper case
# ![Screenshot 2025-02-15 014213.png](data:image/png;base64,...)

# %% [markdown]
# # Camel case
# - myHouseNumber; starts with a lowercase letter and every word after that starts with an uppercase.
#
# # Partial case
# - MyHouseNumber; This is close to camel case except the first word is also in uppercase.
#
# # Underscore
# - my_house_number; you can see each word is separated by an underscore. This is often used in php but also in the javascript world.
# ![Screenshot 2025-02-18 000429.png](data:image/png;base64,...)

# %% [markdown]
# # Arrays
# - Arrays are used to store multiple values in a single variable.
# ![Screenshot 2025-02-18 001140.png](data:image/png;base64,...)

# %% [markdown]
# - To target just the blue color
# ![Screenshot 2025-02-18 001442.png](data:image/png;base64,...)

# %% [markdown]
# - A different way to write an array
# ![Screenshot 2025-02-18 001931.png](data:image/png;base64,...)

# %% [markdown]
# - Adding extra data to an array
# ![Screenshot 2025-02-18 002949.png](data:image/png;base64,...)

# %% [markdown]
# # There's a better way to add to an array.
# - It is called the push function. It is a more correct way to add to an array. This is known as dot syntax, we are taking an object which in this case is an array and wea are calling the push function which we parse in our parameter 'purple'
# ![Screenshot 2025-02-18 003932.png](data:image/png;base64,...)

# %% [markdown]
# - Number array
# ![Screenshot 2025-02-18 010718.png](data:image/png;base64,...)

# %% [markdown]
# You can alert a string using its index
# ![Screenshot 2025-02-22 003139.png](data:image/png;base64,...)

# %% [markdown]
# the .push() is also called method. When you say and functions in Javascript its generally the same thing as well as properties and attributes. Arrays can have properties and methods.
#
# Lets look the property of length because the length pertains to how many values are in the array.
# ![Screenshot 2025-02-22 003759.png](data:image/png;base64,...)

# %% [markdown]
# Method would be just a function just like push that we used initially. There also one called '.sort'. If it is a method or function it has to have parenthesis on the back of it. .sort arranges an array by value
# ![Screenshot 2025-02-22 004325.png](data:image/png;base64,...)

# %% [markdown]
# There's one called reverse. It gives us the reverse order for which it was created.
# ![Screenshot 2025-02-22 004554.png](data:image/png;base64,...)

# %% [markdown]
# # Loops
# There are types of loops similar to those in other programming languages. For instance, you have 'for loop' in javascript, php, java etc. We'd look at 'for', 'while' and 'for each' loop which is used for arrays. What loops do is that they iterate through something whether its an array or a result rows from a database whatever it may be.
# A basic example writing a 'for loop' is; structured just like a function, set a variable 'var i = 0' to begin with. Each paramter is separated by a semicolon. The next is going to be the conditon; we'd say 'as long as i < 10'; this is the condition. The last part is to increment, and we want to increment by 1. To do that we write 'i++' which will increment i by 1. Inside the curly braces is what we want to happen through each iteration. We'd do a console.log. It is a way to print stuff out just similar to what we've been doing with alert.
# ![Screenshot 2025-02-22 014743.png](data:image/png;base64,...)

# %% [markdown]
# With this you can output anything depending on your parameters. We are goign to try and print out a string.![Screenshot 2025-02-22 015159.png](data:image/png;base64,...)
